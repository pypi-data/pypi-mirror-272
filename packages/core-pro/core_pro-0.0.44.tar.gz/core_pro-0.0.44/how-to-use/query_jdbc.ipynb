# %% [raw]
# # 1. Query Data

# %% [markdown]
# Query check

# %%
from core_pro import DataPipeLine


query = """
    select grass_date
    , count(distinct user_id) total_a1
    from mp_user.dws_user_login_1d__vn_s0_live
    where grass_date >= date'2022-01-01'
    group by 1
"""
print(DataPipeLine(query).query)
# Out:
#     select grass_date
#     , count(distinct user_id) total_a1
#     from mp_user.dws_user_login_1d__vn_s0_live
#     where grass_date >= date'2022-01-01'
#     group by 1

# %%
df = DataPipeLine(query).run_presto_to_df()
# Out:
# 🤖 JDBC Status: RUNNING 77.69%, Memory 209GB: : 61it [05:05,  5.00s/it]
# 🐔 JDBC: Data Shape: (622, 2)

# %% [markdown]
# # 2. Threadpool query data

# %% [markdown]
# How to set multi-thread download with different dates

# %%
import polars as pl
from datetime import date, timedelta
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor



def download(date_input):
    """wrapper your download code into a function"""
    # setup file name
    path = Path.home() / 'VSCodeProjects/how-to-use/'
    file_name = path / f'{date_input}.parquet'

    # query
    query = f"""
    select grass_date
    , count(distinct user_id) total_a1
    from mp_user.dws_user_login_1d__vn_s0_live
    where grass_date = date'{date_input}'
    group by 1
    """

    # check if file exist (don't have to download file again)
    if not file_name.exists():
        df = DataPipeLine(query).run_presto_to_df()
        df.write_parquet(file_name, use_pyarrow=True)

# %%
yesterday = date.today() - timedelta(days=1)
dates = pl.date_range(start=date(2023, 9, 8), end=yesterday, interval='2d', eager=True)
run = list(dates)
run
# Out:
# [datetime.date(2023, 9, 8),
#  datetime.date(2023, 9, 10),
#  datetime.date(2023, 9, 12),
#  datetime.date(2023, 9, 14)]

# %%
max_workers = 4   # depend on your CPU
with ThreadPoolExecutor(max_workers) as executor:
    executor.map(download, run)
# Out:
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 0it [00:00, ?it/s]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 2it [00:05,  2.50s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 3it [00:10,  3.54s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 4it [00:15,  4.09s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 5it [00:20,  4.40s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 6it [00:25,  4.60s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 7it [00:30,  4.73s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 8it [00:35,  4.82s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 9it [00:40,  4.87s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 10it [00:45,  4.91s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 11it [00:50,  4.94s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 12it [00:55,  4.96s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 13it [01:00,  4.97s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 14it [01:05,  4.98s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 15it [01:10,  4.99s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 16it [01:15,  4.99s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 17it [01:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 18it [01:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 19it [01:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 20it [01:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 21it [01:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 22it [01:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 23it [01:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 24it [01:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 25it [02:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 26it [02:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 27it [02:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 28it [02:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 29it [02:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 30it [02:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 31it [02:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 32it [02:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 33it [02:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 34it [02:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 35it [02:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 36it [02:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 37it [03:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 38it [03:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 39it [03:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 40it [03:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 41it [03:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 42it [03:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 43it [03:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 44it [03:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 45it [03:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 46it [03:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 47it [03:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 48it [03:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 49it [04:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 50it [04:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 51it [04:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 52it [04:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 53it [04:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 54it [04:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 55it [04:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 56it [04:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 57it [04:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 58it [04:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 59it [04:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 60it [04:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 61it [05:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 62it [05:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 63it [05:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 64it [05:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 65it [05:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 66it [05:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 67it [05:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 68it [05:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 69it [05:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 70it [05:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 71it [05:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 72it [05:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 73it [06:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 74it [06:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 75it [06:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 76it [06:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 77it [06:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 78it [06:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 79it [06:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 80it [06:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 81it [06:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 82it [06:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 83it [06:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 84it [06:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 85it [07:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 86it [07:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 87it [07:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 88it [07:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 89it [07:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 90it [07:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 91it [07:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 92it [07:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 93it [07:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 94it [07:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 95it [07:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 96it [07:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 97it [08:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 98it [08:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 99it [08:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 100it [08:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 101it [08:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 102it [08:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 103it [08:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 104it [08:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 105it [08:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 106it [08:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 107it [08:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 108it [08:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 109it [09:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 110it [09:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 111it [09:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 112it [09:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 113it [09:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 114it [09:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 115it [09:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 116it [09:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 117it [09:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 118it [09:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 119it [09:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 120it [09:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 121it [10:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 122it [10:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 123it [10:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 124it [10:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 125it [10:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: WAITING_FOR_RESOURCES 0%, Memory 0GB: : 126it [10:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 127it [10:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 128it [10:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 129it [10:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 130it [10:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 131it [10:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 132it [10:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 133it [11:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 134it [11:05,  5.01s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 135it [11:10,  5.01s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 136it [11:15,  5.01s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 137it [11:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 138it [11:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 139it [11:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 140it [11:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 141it [11:40,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 142it [11:45,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 143it [11:50,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 144it [11:55,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 145it [12:00,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 146it [12:05,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 147it [12:10,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 148it [12:15,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 149it [12:20,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 150it [12:25,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 151it [12:30,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 152it [12:35,  5.00s/it]
#
#
#
#
#
# 🤖 JDBC Status: QUEUED 0%, Memory 0GB: : 153it [12:40,  5.00s/it]
